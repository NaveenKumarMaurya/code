# %%
import pandas as pd
import numpy as np
import re

# %%
data1=pd.read_csv('Pune_all_data_final.csv')

# %%
data=data1.copy()

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      0
# bhk             0
# price           0
# emi            11
# sq_ft           0
# owners          0
# link            0
# rera            0
# detail        353
# dtype: int64

# %%
if 
[14:18]data['sq_ft'][11979]
# Out:
# '1150'

# %%
x=data['sq_ft'][11979]

# %%
x.startswith('B')
# Out:
# True

# %%
def sqft_ara(data):
    x=data
    if x.startswith('B')==True:
        d=x[14:18]
        
    else:
        d=' '
#         pat = '[\-\s+\d+\.]+(?:sq.ft.|sq,.ft|sqft|sq.ft)'
#         d = re.findall(pat, x)
    return d

# %%
area=[]
for i in range(len(data)):
    area.append(sqft_ara(data['sq_ft'][i]))

# %%
data['property_area']=area

# %%
data
# Out:
#        Unnamed: 0                                               bhk  \
# 0               0         2, 3 BHK Flats for sale in Punawale, Pune
# 1               1            3, 4 BHK Flats for sale in Nigdi, Pune
# 2               2         1, 2 BHK Flats for sale in Pirangut, Pune
# 3               3  2, 3 BHK Flats for sale in Charholi Budruk, Pune
# 4               4         1, 2 BHK Flats for sale in Fursungi, Pune
# ...           ...                                               ...
# 11979       11979               2 BHK Flat for sale in Pashan, Pune
# 11980       11980                2 BHK Flat for sale in Ravet, Pune
# 11981       11981              2 BHK Flat for sale in Bavdhan, Pune
# 11982       11982                3 BHK Flat for sale in Ravet, Pune
# 11983       11983            2 BHK Flat for sale in Tathawade, Pune
#
#                     price                     emi  \
# 0            ₹54 L - 69 L  EMI starts at ₹28.60 K
# ...

# %%
x=data['property_area'][data['property_area']==' '].index

# %%
x
# Out:
# Int64Index([    0,     1,     2,     3,     4,     5,     6,     7,     8,
#                32,
#             ...
#             11765, 11790, 11791, 11792, 11802, 11803, 11804, 11891, 11907,
#             11927],
#            dtype='int64', length=997)

# %%
data.drop(x,inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0         0
# bhk                0
# price              0
# emi                0
# sq_ft              0
# owners             0
# link               0
# rera               0
# detail           340
# property_area      0
# dtype: int64

# %%
data.reset_index(inplace=True)

# %%
data.drop(columns=['index', 'Unnamed: 0'],inplace=True)

# %%
data
# Out:
#                                                 bhk     price  \
# 0      4 BHK Flat for sale in Magarpatta City, Pune  ₹7.75 Cr
# 1        4 BHK Flat for sale in Koregaon Park, Pune   ₹5.0 Cr
# 2         2 BHK Flat for sale in Chokhi Dhani, Pune   ₹69.0 L
# 3              3 BHK Flat for sale in Kharadi, Pune  ₹1.05 Cr
# 4              2 BHK Flat for sale in Kharadi, Pune   ₹87.0 L
# ...                                             ...       ...
# 10982           2 BHK Flat for sale in Pashan, Pune   ₹77.0 L
# 10983            2 BHK Flat for sale in Ravet, Pune   ₹57.0 L
# 10984          2 BHK Flat for sale in Bavdhan, Pune   ₹68.0 L
# 10985            3 BHK Flat for sale in Ravet, Pune   ₹93.0 L
# 10986        2 BHK Flat for sale in Tathawade, Pune   ₹66.0 L
#
#                             emi  \
# 0      EMI starts at ₹3.85 Lacs
# 1      EMI starts at ₹2.48 Lacs
# 2        EMI starts at ₹36.54 K
# 3        EMI starts at ₹52.13 K
# 4        EMI starts at ₹43.19 K
# ...

# %%
# # extracting location from bhk column
# loc=[]
# for i in range(len(data)):
#     x=data['bhk'][i][23:]
#     loc.append(x)
# #     loc.append(x.split()[-2])

# %%
# data['location']=loc

# %%
data
# Out:
#                                                 bhk     price  \
# 0      4 BHK Flat for sale in Magarpatta City, Pune  ₹7.75 Cr
# 1        4 BHK Flat for sale in Koregaon Park, Pune   ₹5.0 Cr
# 2         2 BHK Flat for sale in Chokhi Dhani, Pune   ₹69.0 L
# 3              3 BHK Flat for sale in Kharadi, Pune  ₹1.05 Cr
# 4              2 BHK Flat for sale in Kharadi, Pune   ₹87.0 L
# ...                                             ...       ...
# 10982           2 BHK Flat for sale in Pashan, Pune   ₹77.0 L
# 10983            2 BHK Flat for sale in Ravet, Pune   ₹57.0 L
# 10984          2 BHK Flat for sale in Bavdhan, Pune   ₹68.0 L
# 10985            3 BHK Flat for sale in Ravet, Pune   ₹93.0 L
# 10986        2 BHK Flat for sale in Tathawade, Pune   ₹66.0 L
#
#                             emi  \
# 0      EMI starts at ₹3.85 Lacs
# 1      EMI starts at ₹2.48 Lacs
# 2        EMI starts at ₹36.54 K
# 3        EMI starts at ₹52.13 K
# 4        EMI starts at ₹43.19 K
# ...

# %%
x=data['bhk'][0][23:]
x
# Out:
# 'Magarpatta City, Pune'

# %%
# extracting no of bhk from bhk column
bhk=[]
for i in range(len(data)):
    x=data['bhk'][i]
    bhk.append(re.findall(r'\d+',x))

# %%
data['BHK']=bhk
#BHK done

# %%
# extracting no of bhk from bhk column
emi=[]
for i in range(len(data)):
    emi.append(data['emi'][i][15::])

# %%
data['EMI']=emi

# %%
# extracting ID from link column
id=[]
for i in range(len(data)):
    x=data['link'][i]
    x1=re.findall(r'\d+',x)
    id.append(x1[0])

# %%
data['property_id']=id

# %%
data2=data.copy()

# %%
Property_price=[]
for i in range(len(data)):
    Property_price.append(data2['price'][i].replace('₹',' '))
    
#     print(data['price'])

# %%
data2['PRICE']=Property_price

# %%
data2
# Out:
#                                                 bhk     price  \
# 0      4 BHK Flat for sale in Magarpatta City, Pune  ₹7.75 Cr
# 1        4 BHK Flat for sale in Koregaon Park, Pune   ₹5.0 Cr
# 2         2 BHK Flat for sale in Chokhi Dhani, Pune   ₹69.0 L
# 3              3 BHK Flat for sale in Kharadi, Pune  ₹1.05 Cr
# 4              2 BHK Flat for sale in Kharadi, Pune   ₹87.0 L
# ...                                             ...       ...
# 10982           2 BHK Flat for sale in Pashan, Pune   ₹77.0 L
# 10983            2 BHK Flat for sale in Ravet, Pune   ₹57.0 L
# 10984          2 BHK Flat for sale in Bavdhan, Pune   ₹68.0 L
# 10985            3 BHK Flat for sale in Ravet, Pune   ₹93.0 L
# 10986        2 BHK Flat for sale in Tathawade, Pune   ₹66.0 L
#
#                             emi  \
# 0      EMI starts at ₹3.85 Lacs
# 1      EMI starts at ₹2.48 Lacs
# 2        EMI starts at ₹36.54 K
# 3        EMI starts at ₹52.13 K
# 4        EMI starts at ₹43.19 K
# ...

# %%
p=str(data2['PRICE'][0]).split()
p
# Out:
# ['7.75', 'Cr']

# %%
p[1]
# Out:
# 'Cr'

# %%
float(p[0])*10000
# Out:
# 77500.0

# %%
price2=[]
for i in range(len(data)):
    p=str(data2['PRICE'][i]).split()
    if p[1]=='Cr':
        price2.append(float(p[0])*10000000)
    else:
        price2.append(float(p[0])*100000)

# %%
data2['Price_INR']=price2

# %%
data2
# Out:
#                                                 bhk     price  \
# 0      4 BHK Flat for sale in Magarpatta City, Pune  ₹7.75 Cr
# 1        4 BHK Flat for sale in Koregaon Park, Pune   ₹5.0 Cr
# 2         2 BHK Flat for sale in Chokhi Dhani, Pune   ₹69.0 L
# 3              3 BHK Flat for sale in Kharadi, Pune  ₹1.05 Cr
# 4              2 BHK Flat for sale in Kharadi, Pune   ₹87.0 L
# ...                                             ...       ...
# 10982           2 BHK Flat for sale in Pashan, Pune   ₹77.0 L
# 10983            2 BHK Flat for sale in Ravet, Pune   ₹57.0 L
# 10984          2 BHK Flat for sale in Bavdhan, Pune   ₹68.0 L
# 10985            3 BHK Flat for sale in Ravet, Pune   ₹93.0 L
# 10986        2 BHK Flat for sale in Tathawade, Pune   ₹66.0 L
#
#                             emi  \
# 0      EMI starts at ₹3.85 Lacs
# 1      EMI starts at ₹2.48 Lacs
# 2        EMI starts at ₹36.54 K
# 3        EMI starts at ₹52.13 K
# 4        EMI starts at ₹43.19 K
# ...

# %%
# l=str(data2['location'][0]).split()

# %%
# l[:-1]

# %%
# loc1=[]
# for i in range(len(data)):
#     l=str(data2['location'][i]).split()
#     loc1.append(l[:-1])

# %%
# data2['LOCATION']=loc1

# %%
data2
# Out:
#                                                 bhk     price  \
# 0      4 BHK Flat for sale in Magarpatta City, Pune  ₹7.75 Cr
# 1        4 BHK Flat for sale in Koregaon Park, Pune   ₹5.0 Cr
# 2         2 BHK Flat for sale in Chokhi Dhani, Pune   ₹69.0 L
# 3              3 BHK Flat for sale in Kharadi, Pune  ₹1.05 Cr
# 4              2 BHK Flat for sale in Kharadi, Pune   ₹87.0 L
# ...                                             ...       ...
# 10982           2 BHK Flat for sale in Pashan, Pune   ₹77.0 L
# 10983            2 BHK Flat for sale in Ravet, Pune   ₹57.0 L
# 10984          2 BHK Flat for sale in Bavdhan, Pune   ₹68.0 L
# 10985            3 BHK Flat for sale in Ravet, Pune   ₹93.0 L
# 10986        2 BHK Flat for sale in Tathawade, Pune   ₹66.0 L
#
#                             emi  \
# 0      EMI starts at ₹3.85 Lacs
# 1      EMI starts at ₹2.48 Lacs
# 2        EMI starts at ₹36.54 K
# 3        EMI starts at ₹52.13 K
# 4        EMI starts at ₹43.19 K
# ...

# %%
# x=data2['location'].value_counts()

# %%
# loc_pune=pd.DataFrame(x)

# %%
# loc_pune.reset_index(inplace=True)

# %%
# loc_pune.to_csv('pune_all_location_list.csv')

# %%
emi1=[]
for i in range(len(data)):
    p=str(data2['EMI'][i]).split()
    if p[1]=='Lacs':
        emi1.append(float(p[0])*100000)
    else:
        emi1.append(float(p[0])*1000)

# %%
data2['EMI_INR']=emi1

# %%
data2
# Out:
#                                                 bhk     price  \
# 0      4 BHK Flat for sale in Magarpatta City, Pune  ₹7.75 Cr
# 1        4 BHK Flat for sale in Koregaon Park, Pune   ₹5.0 Cr
# 2         2 BHK Flat for sale in Chokhi Dhani, Pune   ₹69.0 L
# 3              3 BHK Flat for sale in Kharadi, Pune  ₹1.05 Cr
# 4              2 BHK Flat for sale in Kharadi, Pune   ₹87.0 L
# ...                                             ...       ...
# 10982           2 BHK Flat for sale in Pashan, Pune   ₹77.0 L
# 10983            2 BHK Flat for sale in Ravet, Pune   ₹57.0 L
# 10984          2 BHK Flat for sale in Bavdhan, Pune   ₹68.0 L
# 10985            3 BHK Flat for sale in Ravet, Pune   ₹93.0 L
# 10986        2 BHK Flat for sale in Tathawade, Pune   ₹66.0 L
#
#                             emi  \
# 0      EMI starts at ₹3.85 Lacs
# 1      EMI starts at ₹2.48 Lacs
# 2        EMI starts at ₹36.54 K
# 3        EMI starts at ₹52.13 K
# 4        EMI starts at ₹43.19 K
# ...

# %%
List = ["ITEM1", "ITEM2", "ITEM3"]
string_version = "".join(List)

# %%
string_version
# Out:
# 'ITEM1ITEM2ITEM3'

# %%
string_version
# Out:
# 'ITEM1ITEM2ITEM3'

# %%
# Locality=[]
# for i in range(len(data2)):
#     LIST=data2['LOCATION'][i]
#     string_version = " ".join(LIST)
#     Locality.append(string_version)

# %%
# data2['LOCALITY']=Locality

# %%
data2
# Out:
#                                                 bhk     price  \
# 0      4 BHK Flat for sale in Magarpatta City, Pune  ₹7.75 Cr
# 1        4 BHK Flat for sale in Koregaon Park, Pune   ₹5.0 Cr
# 2         2 BHK Flat for sale in Chokhi Dhani, Pune   ₹69.0 L
# 3              3 BHK Flat for sale in Kharadi, Pune  ₹1.05 Cr
# 4              2 BHK Flat for sale in Kharadi, Pune   ₹87.0 L
# ...                                             ...       ...
# 10982           2 BHK Flat for sale in Pashan, Pune   ₹77.0 L
# 10983            2 BHK Flat for sale in Ravet, Pune   ₹57.0 L
# 10984          2 BHK Flat for sale in Bavdhan, Pune   ₹68.0 L
# 10985            3 BHK Flat for sale in Ravet, Pune   ₹93.0 L
# 10986        2 BHK Flat for sale in Tathawade, Pune   ₹66.0 L
#
#                             emi  \
# 0      EMI starts at ₹3.85 Lacs
# 1      EMI starts at ₹2.48 Lacs
# 2        EMI starts at ₹36.54 K
# 3        EMI starts at ₹52.13 K
# 4        EMI starts at ₹43.19 K
# ...

# %%
# loc2=[]
# for i in range(len(data2)):
#     loc2.append(data2['LOCALITY'][i].replace(',',' '))

# %%
# data2.drop(columns='Location',inplace=True)

# %%
# data2['Location']=loc2

# %%
data2
# Out:
#                                                 bhk     price  \
# 0      4 BHK Flat for sale in Magarpatta City, Pune  ₹7.75 Cr
# 1        4 BHK Flat for sale in Koregaon Park, Pune   ₹5.0 Cr
# 2         2 BHK Flat for sale in Chokhi Dhani, Pune   ₹69.0 L
# 3              3 BHK Flat for sale in Kharadi, Pune  ₹1.05 Cr
# 4              2 BHK Flat for sale in Kharadi, Pune   ₹87.0 L
# ...                                             ...       ...
# 10982           2 BHK Flat for sale in Pashan, Pune   ₹77.0 L
# 10983            2 BHK Flat for sale in Ravet, Pune   ₹57.0 L
# 10984          2 BHK Flat for sale in Bavdhan, Pune   ₹68.0 L
# 10985            3 BHK Flat for sale in Ravet, Pune   ₹93.0 L
# 10986        2 BHK Flat for sale in Tathawade, Pune   ₹66.0 L
#
#                             emi  \
# 0      EMI starts at ₹3.85 Lacs
# 1      EMI starts at ₹2.48 Lacs
# 2        EMI starts at ₹36.54 K
# 3        EMI starts at ₹52.13 K
# 4        EMI starts at ₹43.19 K
# ...

# %%
bhk=[]
for i in range(len(data2)):
    LIST=data2['BHK'][i]
    string_version = " ".join(LIST)
    bhk.append(string_version)

# %%
data2['BHK']=bhk

# %%
# data2.drop(columns=['price','location','BHK','EMI','PRICE','LOCATION','LOCALITY'],inplace=True)

# %%
data2
# Out:
#                                                 bhk     price  \
# 0      4 BHK Flat for sale in Magarpatta City, Pune  ₹7.75 Cr
# 1        4 BHK Flat for sale in Koregaon Park, Pune   ₹5.0 Cr
# 2         2 BHK Flat for sale in Chokhi Dhani, Pune   ₹69.0 L
# 3              3 BHK Flat for sale in Kharadi, Pune  ₹1.05 Cr
# 4              2 BHK Flat for sale in Kharadi, Pune   ₹87.0 L
# ...                                             ...       ...
# 10982           2 BHK Flat for sale in Pashan, Pune   ₹77.0 L
# 10983            2 BHK Flat for sale in Ravet, Pune   ₹57.0 L
# 10984          2 BHK Flat for sale in Bavdhan, Pune   ₹68.0 L
# 10985            3 BHK Flat for sale in Ravet, Pune   ₹93.0 L
# 10986        2 BHK Flat for sale in Tathawade, Pune   ₹66.0 L
#
#                             emi  \
# 0      EMI starts at ₹3.85 Lacs
# 1      EMI starts at ₹2.48 Lacs
# 2        EMI starts at ₹36.54 K
# 3        EMI starts at ₹52.13 K
# 4        EMI starts at ₹43.19 K
# ...

# %%
x=data2['sq_ft'][0]
x1=re.findall(r'\d+',x)
x1
# Out:
# ['5745', '13', '49']

# %%
price_per_sqft=[]
for i in range(len(data2)):
    price_per_sqft.append(data2['sq_ft'][i][-13:-7])

# %%
pri_per_sqft=[]
for i in range(len(data2)):
    pri_per_sqft.append(price_per_sqft[i].replace('₹',' '))

# %%
pri_per_sqft
# Out:
# ['13.49 ',
#  '11.36 ',
#  ' 6.27 ',
#  ' 7.50 ',
#  ' 8.29 ',
#  ' 7.62 ',
#  ' 7.28 ',
#  '10.43 ',
#  ' 8.71 ',
#  ' 6.36 ',
#  ' 5.78 ',
#  ' 7.64 ',
#  ' 9.41 ',
#  ' 8.84 ',
#  ' 8.04 ',
#  ' 5.61 ',
#  ' 7.59 ',
#  ' 5.36 ',
#  '10.00 ',
#  ' 4.28 ',
#  ' 5.86 ',
#  ' 8.18 ',
#  ' 8.59 ',
#  ' 6.82 ',
#  ' 7.86 ',
#  ' 6.36 ',
#  ' 6.91 ',
#  ' 5.86 ',
#  ' 6.20 ',
#  ' 6.92 ',
#  ' 9.88 ',
#  ' 8.77 ',
#  ' 5.81 ',
#  ' 6.70 ',
#  ' 4.75 ',
#  ' 5.00 ',
#  ' 4.71 ',
#  ' 5.04 ',
#  ' 6.89 ',
#  ' 6.88 ',
#  ' 4.20 ',
#  '17.56 ',
#  ' 5.67 ',
#  ' 8.16 ',
#  ' 6.42 ',
#  ' 6.02 ',
#  ' 8.99 ',
#  '10.44 ',
#  ' 9.17 ',
#  ' 6.63 ',
#  ' 6.72 ',
#  ' 4.65 ',
#  ' 7.68 ',
#  ' 5.76 ',
#  ' 5.51 ',
#  ' 7.82 ',
#  ' 8.74 ',
#  ' 7.14 ',
#  ' 8.81 ',
#  '17.86 ',
#  ' 7.65 ',
#  ' 5.87 ',
#  ' 7.25 ',
#  ' 7.33 ',
#  ' 9.98 ',
#  ' 9.46 ',
#  ' 7.83 ',
#  ' 6.35 ',
#  ' 4.20 ',
#  ' 4.85 ',
#  ' 5.27 ',
#  ' 6.56 ',
#  '12.00 ',
#  ' 5.46 ',
#  ' 9.43 ',
#  ' 5.69 ',
# ...

# %%
p_sqft=[]
for i in range(len(pri_per_sqft)):
    LIST=pri_per_sqft[i]
    string_version = "".join(LIST)
    p_sqft.append(string_version)

# %%
float(p_sqft[0])*1000
# Out:
# 13490.0

# %%
p_sqft1=[]
for i in range(len(p_sqft)):
    try:
        p_sqft1.append(float(p_sqft[i])*1000)
    except:
        p_sqft1.append(' ')

# %%
data2['Price_per_sqft_INR']=p_sqft1

# %%
data2
# Out:
#                                                 bhk     price  \
# 0      4 BHK Flat for sale in Magarpatta City, Pune  ₹7.75 Cr
# 1        4 BHK Flat for sale in Koregaon Park, Pune   ₹5.0 Cr
# 2         2 BHK Flat for sale in Chokhi Dhani, Pune   ₹69.0 L
# 3              3 BHK Flat for sale in Kharadi, Pune  ₹1.05 Cr
# 4              2 BHK Flat for sale in Kharadi, Pune   ₹87.0 L
# ...                                             ...       ...
# 10982           2 BHK Flat for sale in Pashan, Pune   ₹77.0 L
# 10983            2 BHK Flat for sale in Ravet, Pune   ₹57.0 L
# 10984          2 BHK Flat for sale in Bavdhan, Pune   ₹68.0 L
# 10985            3 BHK Flat for sale in Ravet, Pune   ₹93.0 L
# 10986        2 BHK Flat for sale in Tathawade, Pune   ₹66.0 L
#
#                             emi  \
# 0      EMI starts at ₹3.85 Lacs
# 1      EMI starts at ₹2.48 Lacs
# 2        EMI starts at ₹36.54 K
# 3        EMI starts at ₹52.13 K
# 4        EMI starts at ₹43.19 K
# ...

# %%
# data2.drop(columns=['emi','sq_ft'],inplace=True)

# %%
data2
# Out:
#                                                 bhk     price  \
# 0      4 BHK Flat for sale in Magarpatta City, Pune  ₹7.75 Cr
# 1        4 BHK Flat for sale in Koregaon Park, Pune   ₹5.0 Cr
# 2         2 BHK Flat for sale in Chokhi Dhani, Pune   ₹69.0 L
# 3              3 BHK Flat for sale in Kharadi, Pune  ₹1.05 Cr
# 4              2 BHK Flat for sale in Kharadi, Pune   ₹87.0 L
# ...                                             ...       ...
# 10982           2 BHK Flat for sale in Pashan, Pune   ₹77.0 L
# 10983            2 BHK Flat for sale in Ravet, Pune   ₹57.0 L
# 10984          2 BHK Flat for sale in Bavdhan, Pune   ₹68.0 L
# 10985            3 BHK Flat for sale in Ravet, Pune   ₹93.0 L
# 10986        2 BHK Flat for sale in Tathawade, Pune   ₹66.0 L
#
#                             emi  \
# 0      EMI starts at ₹3.85 Lacs
# 1      EMI starts at ₹2.48 Lacs
# 2        EMI starts at ₹36.54 K
# 3        EMI starts at ₹52.13 K
# 4        EMI starts at ₹43.19 K
# ...

# %%
data2.to_csv('Pune_all_location_11000_data_for_shivani.csv')

# %%
x=data2['Location'][0]

# %%
x.split

# %%
data2
# Out:
#                                                 bhk     price  \
# 0      4 BHK Flat for sale in Magarpatta City, Pune  ₹7.75 Cr
# 1        4 BHK Flat for sale in Koregaon Park, Pune   ₹5.0 Cr
# 2         2 BHK Flat for sale in Chokhi Dhani, Pune   ₹69.0 L
# 3              3 BHK Flat for sale in Kharadi, Pune  ₹1.05 Cr
# 4              2 BHK Flat for sale in Kharadi, Pune   ₹87.0 L
# ...                                             ...       ...
# 10982           2 BHK Flat for sale in Pashan, Pune   ₹77.0 L
# 10983            2 BHK Flat for sale in Ravet, Pune   ₹57.0 L
# 10984          2 BHK Flat for sale in Bavdhan, Pune   ₹68.0 L
# 10985            3 BHK Flat for sale in Ravet, Pune   ₹93.0 L
# 10986        2 BHK Flat for sale in Tathawade, Pune   ₹66.0 L
#
#                             emi  \
# 0      EMI starts at ₹3.85 Lacs
# 1      EMI starts at ₹2.48 Lacs
# 2        EMI starts at ₹36.54 K
# 3        EMI starts at ₹52.13 K
# 4        EMI starts at ₹43.19 K
# ...

# %%
data2

# %%
loc=[]
for i in data2['bhk']:
    pat = 'in ([\w+\s+]+)'
    d = re.findall(pat,i)
    loc.append(d)
    print(d)
# Out:
# ['Magarpatta City']
# ['Koregaon Park']
# ['Chokhi Dhani']
# ['Kharadi']
# ['Kharadi']
# ['Kharadi']
# ['Kharadi']
# ['Mundhwa']
# ['Kharadi']
# ['Kharadi']
# ['Lohegaon']
# ['Bavdhan']
# ['Koregaon Park']
# ['Baner']
# ['Baner']
# ['Sus']
# ['Magarpatta City']
# ['Hinjewadi Phase 3']
# ['Wanwadi']
# ['Undri']
# ['Kondhwa']
# ['Bavdhan']
# ['Kharadi']
# ['Wakad']
# ['Maan']
# ['Keshav Nagar']
# ['Maan']
# ['Tathawade']
# ['Wakad']
# ['Pimple Nilakh']
# ['Baner']
# ['Kharadi']
# ['Bavdhan']
# ['Keshav Nagar']
# ['Talegaon Dabhade']
# ['Hadapsar']
# ['Dhayari']
# ['Handewadi']
# ['Wadgaon Sheri']
# ['Hinjewadi']
# ['Pisoli']
# ['Pashan']
# ['Kharadi']
# ['Tathawade']
# ['Punawale']
# ['Wakad']
# ['Pimple Saudagar']
# ['Balewadi']
# ['Mohammed Wadi']
# ['Hinjewadi']
# ['Keshav Nagar']
# ['Talegaon Dabhade']
# ['Mundhwa']
# ['Dhayari']
# ['Undri']
# ['Wadgaon Sheri']
# ['Thergaon']
# ['Mohammed Wadi']
# ['Mahalunge']
# ['Viman Nagar']
# ['Maan']
# ['Punawale']
# ['Tathawade']
# ...

# %%
loc
# Out:
# [['Magarpatta City'],
#  ['Koregaon Park'],
#  ['Chokhi Dhani'],
#  ['Kharadi'],
#  ['Kharadi'],
#  ['Kharadi'],
#  ['Kharadi'],
#  ['Mundhwa'],
#  ['Kharadi'],
#  ['Kharadi'],
#  ['Lohegaon'],
#  ['Bavdhan'],
#  ['Koregaon Park'],
#  ['Baner'],
#  ['Baner'],
#  ['Sus'],
#  ['Magarpatta City'],
#  ['Hinjewadi Phase 3'],
#  ['Wanwadi'],
#  ['Undri'],
#  ['Kondhwa'],
#  ['Bavdhan'],
#  ['Kharadi'],
#  ['Wakad'],
#  ['Maan'],
#  ['Keshav Nagar'],
#  ['Maan'],
#  ['Tathawade'],
#  ['Wakad'],
#  ['Pimple Nilakh'],
#  ['Baner'],
#  ['Kharadi'],
#  ['Bavdhan'],
#  ['Keshav Nagar'],
#  ['Talegaon Dabhade'],
#  ['Hadapsar'],
#  ['Dhayari'],
#  ['Handewadi'],
#  ['Wadgaon Sheri'],
#  ['Hinjewadi'],
#  ['Pisoli'],
#  ['Pashan'],
#  ['Kharadi'],
#  ['Tathawade'],
#  ['Punawale'],
#  ['Wakad'],
#  ['Pimple Saudagar'],
#  ['Balewadi'],
#  ['Mohammed Wadi'],
#  ['Hinjewadi'],
#  ['Keshav Nagar'],
#  ['Talegaon Dabhade'],
#  ['Mundhwa'],
#  ['Dhayari'],
#  ['Undri'],
#  ['Wadgaon Sheri'],
# ...

# %%
loc1=[]


for i in range(len(loc)):
    LIST=loc[i]
    string_version = "".join(LIST)
    loc1.append(string_version)

# %%
data2[]loc1
# Out:
# ['Magarpatta City',
#  'Koregaon Park',
#  'Chokhi Dhani',
#  'Kharadi',
#  'Kharadi',
#  'Kharadi',
#  'Kharadi',
#  'Mundhwa',
#  'Kharadi',
#  'Kharadi',
#  'Lohegaon',
#  'Bavdhan',
#  'Koregaon Park',
#  'Baner',
#  'Baner',
#  'Sus',
#  'Magarpatta City',
#  'Hinjewadi Phase 3',
#  'Wanwadi',
#  'Undri',
#  'Kondhwa',
#  'Bavdhan',
#  'Kharadi',
#  'Wakad',
#  'Maan',
#  'Keshav Nagar',
#  'Maan',
#  'Tathawade',
#  'Wakad',
#  'Pimple Nilakh',
#  'Baner',
#  'Kharadi',
#  'Bavdhan',
#  'Keshav Nagar',
#  'Talegaon Dabhade',
#  'Hadapsar',
#  'Dhayari',
#  'Handewadi',
#  'Wadgaon Sheri',
#  'Hinjewadi',
#  'Pisoli',
#  'Pashan',
#  'Kharadi',
#  'Tathawade',
#  'Punawale',
#  'Wakad',
#  'Pimple Saudagar',
#  'Balewadi',
#  'Mohammed Wadi',
#  'Hinjewadi',
#  'Keshav Nagar',
#  'Talegaon Dabhade',
#  'Mundhwa',
#  'Dhayari',
#  'Undri',
#  'Wadgaon Sheri',
#  'Thergaon',
#  'Mohammed Wadi',
#  'Mahalunge',
#  'Viman Nagar',
#  'Maan',
#  'Punawale',
#  'Tathawade',
# ...

# %%
data2['location']=loc1

# %%
 data2.drop(columns=['bhk','price','emi','sq_ft','EMI','PRICE'],inplace=True)

# %%
data2.head(1)
# Out:
#                                             bhk     price  \
# 0  4 BHK Flat for sale in Magarpatta City, Pune  ₹7.75 Cr
#
#                         emi  \
# 0  EMI starts at ₹3.85 Lacs
#
#                                                sq_ft       owners  \
# 0  Build Up Area\n5745 sq.ft\nAvg. Price\n₹13.49 ...  Rock Realty
#
#                                                 link      rera  \
# 0  https://housing.com/in/buy/resale/page/8312068...  NOT RERA
#
#                                               detail property_area BHK  \
# 0  The ultra luxurious apartments at YooPune are ...          5745   4
#
#          EMI property_id     PRICE   Price_INR   EMI_INR Price_per_sqft_INR  \
# 0  3.85 Lacs     8312068   7.75 Cr  77500000.0  385000.0            13490.0
#
#           location
# 0  Magarpatta City

# %%
data2.to_csv('pune_11000_final_data.csv')

# %%
loc=data2['location'].value_counts()

# %%
loc.to_csv('PUNE_ALL_LOCATION.csv')

# %%
pune_rent_data=pd.read_csv(r'C:\Users\naveen.maurya\Downloads\Pune_rent.csv')

# %%
pune_rent_data
# Out:
#        Unnamed: 0                          listing  BHK          Feature  \
# 0               0  Authentic ListingsTrusted Agent  2.0   Semi Furnished
# 1               1  Authentic ListingsTrusted Agent  2.0  Fully Furnished
# 2               2  Authentic ListingsTrusted Agent  1.0      Unfurnished
# 3               3  Authentic ListingsTrusted Agent  2.0   Semi Furnished
# 4               4  Authentic ListingsTrusted Agent  2.0   Semi Furnished
# ...           ...                              ...  ...              ...
# 39985       39985                     Not provided  2.0   Semi Furnished
# 39986       39986                     Not provided  2.0   Semi Furnished
# 39987       39987                     Not provided  1.0   Semi Furnished
# 39988       39988                     Not provided  5.0  Fully Furnished
# 39989       39989                     Not provided  2.0   Semi Furnished
#
#                Locality                    Project_name  Area_Sqft  \
# ...

# %%
loc1=[]
for i in pune_rent_data['Locality']:
    pat = 'in ([\w+\s+]+)'
    d = re.findall(pat,i)
    loc.append(d)
    print(d)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\NAVEEN~1.MAU\AppData\Local\Temp/ipykernel_24904/698601169.py in <module>
#       3     pat = 'in ([\w+\s+]+)'
#       4     d = re.findall(pat,i)
# ----> 5     loc.append(d)
#       6     print(d)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in append(self, to_append, ignore_index, verify_integrity)
#    2875             msg = "to_append should be a Series or list/tuple of Series, got DataFrame"
#    2876             raise TypeError(msg)
# -> 2877         return concat(
#    2878             to_concat, ignore_index=ignore_index, verify_integrity=verify_integrity
#    2879         )
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# ...
